# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
pil = Image.open("meinkurta2.jpg")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=674x1352 at 0x165BFCE9B20>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1352, 674, 3)

# %%
cut = arr[:300, :500]

# %%
plt.imshow(cut)

# %%
red = arr[100:200 ,: ,0]

# %%
plt.imshow(red)

# %%
work =arr.copy()

# %%
work[:,:,[1,2]]=255

# %%
plt.imshow(work)
