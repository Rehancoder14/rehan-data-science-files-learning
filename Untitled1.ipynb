# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-662c2f3f4f43> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 from matplotlib import pyplot as plt
# ----> 3 from matplotlib import style1
#
# ImportError: cannot import name 'style1' from 'matplotlib' (C:\Users\user\anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
plt.plot([1,2,3],[0,1,3])

# %%
plt.title("Rehan graph")
# Out:
# Text(0.5, 1.0, 'Rehan graph')

# %%
plt.show()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use("ggplot")
x = [1,5,4]
y = [20,23,26]
x2 = [12,32,4]
y2 = [10,21,33]
plt.plot(x,y)
plt.plot(x2,y2)

# %%
from matplotlib import pyplot as plt
from matplotlib import style


import numpy as np
style.use("ggplot")
y = np.array([35, 25, 25, 15])
plt.title("pichart")
lib =["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels = lib,startangle = 90,explode =  [0.2, 0, 0.2, 0,],shadow = True
)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()
