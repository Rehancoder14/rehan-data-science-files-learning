# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\datasets\\Social_Network_Ads_logistic regression.csv")

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df.drop(["User ID"],axis = 1, inplace=True)

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
gender_to_idx = {"Male":0, "Female":1}
df.replace(gender_to_idx, inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Gender  Age  EstimatedSalary  Purchased
# 0         0   19            19000          0
# 1         0   35            20000          0
# 2         1   26            43000          0
# 3         1   27            57000          0
# 4         0   19            76000          0
# ..      ...  ...              ...        ...
# 395       1   46            41000          1
# 396       0   51            23000          1
# 397       1   50            20000          1
# 398       0   36            33000          0
# 399       1   49            36000          1
#
# [400 rows x 4 columns]>

# %%
sns.pairplot(df)

# %%
idx_0 = df[df["Purchased"]==0].index
idx_1= df[df["Purchased"]==1].index
plt.title("Age/Salary vs AdS Purchase")
plt.plot(df["Age"][idx_0],df["EstimatedSalary"][idx_0], "bo", label="Not Purchased")
plt.plot(df["Age"][idx_0],df["EstimatedSalary"][idx_1], "ro", label="Not Purchased")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_800/2568238070.py in <module>
#       3 plt.title("Age/Salary vs AdS Purchase")
#       4 plt.plot(df["Age"][idx_0],df["EstimatedSalary"][idx_0], "bo", label="Not Purchased")
# ----> 5 plt.plot(df["Age"][idx_0],df["EstimatedSalary"][idx_1], "ro", label="Not Purchased")
#       6
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
