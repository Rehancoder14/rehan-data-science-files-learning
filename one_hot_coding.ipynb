# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\datasets\\loan-test.csv")

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.Property_Area.value_counts()
# Out:
# Urban        140
# Semiurban    116
# Rural        111
# Name: Property_Area, dtype: int64

# %%
pd.get_dummies(df.Property_Area)
# Out:
#      Rural  Semiurban  Urban
# 0        0          0      1
# 1        0          0      1
# 2        0          0      1
# 3        0          0      1
# 4        0          0      1
# ..     ...        ...    ...
# 362      0          0      1
# 363      0          0      1
# 364      0          1      0
# 365      1          0      0
# 366      1          0      0
#
# [367 rows x 3 columns]

# %%
df.shape
# Out:
# (367, 12)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # instance for labelencoder

# %%
df.Gender = le.fit_transform(df.Gender)

# %%
df.Married = le.fit_transform(df.Married)

# %%
df.Education = le.fit_transform(df.Education)
df.Self_Employed = le.fit_transform(df.Self_Employed)
df.Property_Area = le.fit_transform(df.Property_Area)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1         3+          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  367.000000  367.000000  367.000000     367.000000       367.000000
# mean     0.839237    0.634877    0.228883       0.226158      4805.599455
# std      0.442036    0.482122    0.420687       0.548791      4910.685399
# min      0.000000    0.000000    0.000000       0.000000         0.000000
# 25%      1.000000    0.000000    0.000000       0.000000      2864.000000
# 50%      1.000000    1.000000    0.000000       0.000000      3786.000000
# 75%      1.000000    1.000000    0.000000       0.000000      5060.000000
# max      2.000000    1.000000    1.000000       2.000000     72529.000000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count         367.000000  362.000000        361.000000      338.000000
# mean         1569.577657  136.132597        342.537396        0.825444
# std          2334.232099   61.366652         65.156643        0.380150
# ...

# %%
df.isnull().head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    False   False    False       False      False          False
# 1    False   False    False       False      False          False
# 2    False   False    False       False      False          False
# 3    False   False    False       False      False          False
# 4    False   False    False       False      False          False
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            False              False       False             False
# 1            False              False       False             False
# 2            False              False       False             False
# 3            False              False       False             False
# 4            False              False       False             False
#
#    Credit_History  Property_Area
# 0           False          False
# 1           False          False
# 2           False          False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df[df["Dependents"].isnull()]
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 46   LP001237       1        1        NaN          1              0
# 70   LP001366       0        0        NaN          0              0
# 111  LP001587       1        1        NaN          0              0
# 138  LP001769       2        0        NaN          0              0
# 202  LP002111       1        1        NaN          0              0
# 247  LP002360       1        1        NaN          0              0
# 251  LP002385       1        1        NaN          0              0
# 265  LP002441       1        0        NaN          0              0
# 302  LP002654       0        0        NaN          0              1
# 312  LP002754       1        0        NaN          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 46              4163               1475       162.0             360.0
# 70              3250                  0        95.0             360.0
# ...

# %%
df[df["LoanAmount"].isnull()]
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 78   LP001415       1        1          1          0              0
# 101  LP001542       0        1          0          0              0
# 188  LP002057       1        1          0          1              0
# 247  LP002360       1        1        NaN          0              0
# 289  LP002593       1        1          1          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 78              3413               4053         NaN             360.0
# 101             2262                  0         NaN             480.0
# 188            13083                  0         NaN             360.0
# 247            10000                  0         NaN             360.0
# 289             8333               4000         NaN             360.0
#
#      Credit_History  Property_Area
# 78              1.0              1
# 101             0.0              1
# ...

# %%
df[df["Loan_Amount_Term"].isnull()]
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 45   LP001232       1        1          0          0              0
# 48   LP001268       1        0          0          0              0
# 117  LP001611       1        1          1          0              0
# 129  LP001695       1        1          1          1              0
# 184  LP002045       1        1         3+          0              0
# 214  LP002183       1        1          0          1              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 45              4260               3900       185.0               NaN
# 48              6792               3338       187.0               NaN
# 117             1516               2900        80.0               NaN
# 129             3321               2088        70.0               NaN
# 184            10166                750       150.0               NaN
# ...

# %%
df[df["Credit_History"].isnull()]
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 3    LP001035       1        1          2          0              0
# 12   LP001083       1        0         3+          0              0
# 26   LP001163       1        1          2          0              0
# 28   LP001174       1        1          0          0              0
# 45   LP001232       1        1          0          0              0
# 90   LP001475       1        1          0          0              1
# 99   LP001527       1        1         3+          0              0
# 104  LP001558       1        0          0          0              0
# 115  LP001601       1        0         3+          0              0
# 139  LP001771       0        0         3+          0              0
# 143  LP001791       1        1          0          0              1
# 164  LP001921       1        0          1          0              0
# 177  LP002009       0        0          0          0              0
# ...

# %%
df.shape
# Out:
# (367, 12)

# %%
df.dropna(how="any").shape
# Out:
# (321, 12)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1         3+          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.dropna(subset=["Dependents","Credit_History"],how="any").shape
# Out:
# (330, 12)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1         3+          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
plt.scatter(df["ApplicantIncome"],df["CoapplicantIncome"])
